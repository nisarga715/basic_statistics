# %%
#Descriptive Analytics for Numerical Columns

import pandas as pd
df=pd.read_csv(r"C:\Users\HP\OneDrive\Desktop\datascience2025\assignments\sales_data_with_discounts.csv")
df
# Out:
#            Date       Day  SKU City  Volume         BU  Brand       Model  \
# 0    01-04-2021  Thursday  M01    C      15    Mobiles  RealU       RU-10
# 1    01-04-2021  Thursday  M02    C      10    Mobiles  RealU   RU-9 Plus
# 2    01-04-2021  Thursday  M03    C       7    Mobiles   YouM       YM-99
# 3    01-04-2021  Thursday  M04    C       6    Mobiles   YouM  YM-99 Plus
# 4    01-04-2021  Thursday  M05    C       3    Mobiles   YouM      YM-98
# ..          ...       ...  ...  ...     ...        ...    ...         ...
# 445  15-04-2021  Thursday  L06    C       2  Lifestyle  Jeera   M-Casuals
# 446  15-04-2021  Thursday  L07    C       6  Lifestyle   Viva   W-Western
# 447  15-04-2021  Thursday  L08    C       2  Lifestyle   Viva    W-Lounge
# 448  15-04-2021  Thursday  L09    C       3  Lifestyle  Jeera   M-Formals
# 449  15-04-2021  Thursday  L10    C       1  Lifestyle  Jeera     M-Shoes
#
#      Avg Price  Total Sales Value  Discount Rate (%)  Discount Amount  \
# ...

# %%
df.shape

#total rows and column
# Out:
# (450, 13)

# %%
df.columns

#total column names
# Out:
# Index(['Date', 'Day', 'SKU', 'City', 'Volume', 'BU', 'Brand', 'Model',
#        'Avg Price', 'Total Sales Value', 'Discount Rate (%)',
#        'Discount Amount', 'Net Sales Value'],
#       dtype='object')

# %%
# To Calculate the mean, median, mode, and standard deviation for these columns.
#and also to find count, 25%, 50%, 75%, max all at once
#these are derived from boxplot

df.describe()
# Out:
#            Volume     Avg Price  Total Sales Value  Discount Rate (%)  \
# count  450.000000    450.000000         450.000000         450.000000
# mean     5.066667  10453.433333       33812.835556          15.155242
# std      4.231602  18079.904840       50535.074173           4.220602
# min      1.000000    290.000000         400.000000           5.007822
# 25%      3.000000    465.000000        2700.000000          13.965063
# 50%      4.000000   1450.000000        5700.000000          16.577766
# 75%      6.000000  10100.000000       53200.000000          18.114718
# max     31.000000  60100.000000      196400.000000          19.992407
#
#        Discount Amount  Net Sales Value
# count       450.000000       450.000000
# mean       3346.499424     30466.336131
# std        4509.902963     46358.656624
# min          69.177942       326.974801
# 25%         460.459304      2202.208645
# 50%         988.933733      4677.788059
# 75%        5316.495426     47847.912855
# ...

# %%
df.info()

#coulmns and their datatypes
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 450 entries, 0 to 449
# Data columns (total 13 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Date               450 non-null    object
#  1   Day                450 non-null    object
#  2   SKU                450 non-null    object
#  3   City               450 non-null    object
#  4   Volume             450 non-null    int64
#  5   BU                 450 non-null    object
#  6   Brand              450 non-null    object
#  7   Model              450 non-null    object
#  8   Avg Price          450 non-null    int64
#  9   Total Sales Value  450 non-null    int64
#  10  Discount Rate (%)  450 non-null    float64
#  11  Discount Amount    450 non-null    float64
#  12  Net Sales Value    450 non-null    float64
# dtypes: float64(3), int64(3), object(7)
# memory usage: 45.8+ KB

# %%
df.isnull()

#to find null value
# Out:
#       Date    Day    SKU   City  Volume     BU  Brand  Model  Avg Price  \
# 0    False  False  False  False   False  False  False  False      False
# 1    False  False  False  False   False  False  False  False      False
# 2    False  False  False  False   False  False  False  False      False
# 3    False  False  False  False   False  False  False  False      False
# 4    False  False  False  False   False  False  False  False      False
# ..     ...    ...    ...    ...     ...    ...    ...    ...        ...
# 445  False  False  False  False   False  False  False  False      False
# 446  False  False  False  False   False  False  False  False      False
# 447  False  False  False  False   False  False  False  False      False
# 448  False  False  False  False   False  False  False  False      False
# 449  False  False  False  False   False  False  False  False      False
#
#      Total Sales Value  Discount Rate (%)  Discount Amount  Net Sales Value
# ...

# %%
df.isnull().sum()

#to find total null values
# Out:
# Date                 0
# Day                  0
# SKU                  0
# City                 0
# Volume               0
# BU                   0
# Brand                0
# Model                0
# Avg Price            0
# Total Sales Value    0
# Discount Rate (%)    0
# Discount Amount      0
# Net Sales Value      0
# dtype: int64

# %%
df.hist()
# Out:
# array([[<Axes: title={'center': 'Volume'}>,
#         <Axes: title={'center': 'Avg Price'}>],
#        [<Axes: title={'center': 'Total Sales Value'}>,
#         <Axes: title={'center': 'Discount Rate (%)'}>],
#        [<Axes: title={'center': 'Discount Amount'}>,
#         <Axes: title={'center': 'Net Sales Value'}>]], dtype=object)

# %%
#HISTOGRAM

df.hist(figsize=(12,6))
# Out:
# array([[<Axes: title={'center': 'Volume'}>,
#         <Axes: title={'center': 'Avg Price'}>],
#        [<Axes: title={'center': 'Total Sales Value'}>,
#         <Axes: title={'center': 'Discount Rate (%)'}>],
#        [<Axes: title={'center': 'Discount Amount'}>,
#         <Axes: title={'center': 'Net Sales Value'}>]], dtype=object)

# %%
import matplotlib.pyplot as plt
import seaborn as sns
plt.hist(df['Net Sales Value'])
plt.show()

# %%
df.columns
# Out:
# Index(['Date', 'Day', 'SKU', 'City', 'Volume', 'BU', 'Brand', 'Model',
#        'Avg Price', 'Total Sales Value', 'Discount Rate (%)',
#        'Discount Amount', 'Net Sales Value'],
#       dtype='object')

# %%
plt.hist(df['Discount Amount'])
plt.show()

# %%
plt.hist(df['Volume'])
plt.show()

# %%
plt.hist(df['Total Sales Value'])
plt.show()

# %%
plt.hist(df['Discount Rate (%)'])
plt.show()

# %%
plt.hist(df['Avg Price'])
plt.show()

# %%
from scipy.stats import skew
print("skew of the raw data %f"%df['Discount Rate (%)'].skew())

#This is negatively skewed
# Out:
# skew of the raw data -1.062294

# %%
from scipy.stats import skew
print("skew of the raw data %f"%df['Net Sales Value'].skew())

#This is positively skewed
# Out:
# skew of the raw data 1.540822

# %%
from scipy.stats import skew
print("skew of the raw data %f"%df['Volume'].skew())

#this is positively skewed
# Out:
# skew of the raw data 2.731724

# %%
#BOXPLOTS
import matplotlib.pyplot as plt
import seaborn as sns
plt.xlabel("number of days")
plt.ylabel("Total bill spent")
plt.title("Boxplot of number of days versus total bill spent")
sns.boxplot(x='Volume', y='Net Sales Value', data=df)
plt.show()

# %%
df.boxplot()

#as we can see we'll infer that there are outliers and unusual distributions, but more in 
# sales, sales value avg price count amount
# Out:
# <Axes: >

# %%
#BAR CHART
#some of the categorical columns are : 
#'Day', 'SKU', 'City', 'Volume', 'BU', 'Brand', 'Model'

x=df['BU']
y=df['Volume']
plt.bar(x, y)
plt.show()

# %%
x=df['Brand']
y=df['Total Sales Value']
plt.bar(x, y)
plt.show()

# %%
x=df['SKU']
y=df['Avg Price']
plt.bar(x, y)
plt.show()

# %%
#Standardization of Numerical Variables
#concept of z-score 
# Standardization is a technique used to scale numerical variables for uniformity, making them more suitable for analytical models. 
# It ensures that all features have a mean of 0 and a standard deviation of 1, preventing variables with larger scales from dominating the analysis.

# %%
# x=df.iloc[:,:-1]
# x

# %%
# x=df.drop('Date', axis=1)
# x

# %%
#Conversion of Categorical Data into Dummy Variables

#THE NEED FOR ONE-HOT-ENCODING : 
#one hot encoding it is a techniques that transforms categorical to numerical 
#it converts categorical variable into a dummy variables (1-True, 0=False)

#APPLYING ONE-HOT-ENCODING TO CATEGORICAL COLUM 'BU' 
# bu=pd.get_dummies(x['BU'], drop_first=True)
# bu

# %%
# x=x.drop('BU',axis=1)

# %%
# x=pd.concat([x,bu],axis=1)
# x

#DISPLAYING THE PORTION OF TRANSFORMED DATASET

# %%
# df.columns

# %%
# CONVERT TRUE OR FALSE TO 1 IN ONE HOT ENCODING

# %%
# Calculate z-scores
df['Z-Score'] = (df['Net Sales Value'] - df['Net Sales Value'].mean()) / df['Net Sales Value'].std()

print(df)
# Out:
#            Date       Day  SKU City  Volume         BU  Brand       Model  \
# 0    01-04-2021  Thursday  M01    C      15    Mobiles  RealU       RU-10
# 1    01-04-2021  Thursday  M02    C      10    Mobiles  RealU   RU-9 Plus
# 2    01-04-2021  Thursday  M03    C       7    Mobiles   YouM       YM-99
# 3    01-04-2021  Thursday  M04    C       6    Mobiles   YouM  YM-99 Plus
# 4    01-04-2021  Thursday  M05    C       3    Mobiles   YouM      YM-98
# ..          ...       ...  ...  ...     ...        ...    ...         ...
# 445  15-04-2021  Thursday  L06    C       2  Lifestyle  Jeera   M-Casuals
# 446  15-04-2021  Thursday  L07    C       6  Lifestyle   Viva   W-Western
# 447  15-04-2021  Thursday  L08    C       2  Lifestyle   Viva    W-Lounge
# 448  15-04-2021  Thursday  L09    C       3  Lifestyle  Jeera   M-Formals
# 449  15-04-2021  Thursday  L10    C       1  Lifestyle  Jeera     M-Shoes
#
#      Avg Price  Total Sales Value  Discount Rate (%)  Discount Amount  \
# ...
